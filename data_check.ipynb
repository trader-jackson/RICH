# %%
import glob

csv_files = glob.glob('data\cn_stocks\hs300\preprocessed/*.csv')
print(csv_files)
# Out:
# ['data\\cn_stocks\\hs300\\preprocessed\\000001.SZ.csv', 'data\\cn_stocks\\hs300\\preprocessed\\000002.SZ.csv', 'data\\cn_stocks\\hs300\\preprocessed\\000063.SZ.csv', 'data\\cn_stocks\\hs300\\preprocessed\\000069.SZ.csv', 'data\\cn_stocks\\hs300\\preprocessed\\000100.SZ.csv', 'data\\cn_stocks\\hs300\\preprocessed\\000157.SZ.csv', 'data\\cn_stocks\\hs300\\preprocessed\\000166.SZ.csv', 'data\\cn_stocks\\hs300\\preprocessed\\000301.SZ.csv', 'data\\cn_stocks\\hs300\\preprocessed\\000338.SZ.csv', 'data\\cn_stocks\\hs300\\preprocessed\\000408.SZ.csv', 'data\\cn_stocks\\hs300\\preprocessed\\000425.SZ.csv', 'data\\cn_stocks\\hs300\\preprocessed\\000538.SZ.csv', 'data\\cn_stocks\\hs300\\preprocessed\\000568.SZ.csv', 'data\\cn_stocks\\hs300\\preprocessed\\000596.SZ.csv', 'data\\cn_stocks\\hs300\\preprocessed\\000625.SZ.csv', 'data\\cn_stocks\\hs300\\preprocessed\\000651.SZ.csv', 'data\\cn_stocks\\hs300\\preprocessed\\000661.SZ.csv', 'data\\cn_stocks\\hs300\\preprocessed\\000708.SZ.csv', 'data\\
# ...

# %%
import pandas as pd
total=[]
for csv in csv_files:
    total.append(pd.read_csv(csv))
total=pd.concat(total)
total
# Out:
#            index     price     close      high       low      open    volume  \
# 0     2010-01-04  6.781488  0.338825  0.351258  0.338396  0.350400 -0.502301
# 1     2010-01-05  6.664220  0.332966  0.341540  0.325106  0.339397  0.600749
# 2     2010-01-06  6.549814  0.327250  0.332252  0.324678  0.332252  0.094569
# 3     2010-01-07  6.478310  0.323677  0.329394  0.320105  0.327250 -0.104620
# 4     2010-01-08  6.464007  0.322963  0.325106  0.319390  0.321534 -0.338829
# ...          ...       ...       ...       ...       ...       ...       ...
# 3635  2024-12-23  6.840000  0.651429  0.654286  0.640000  0.640952  1.237015
# 3636  2024-12-24  6.950000  0.661905  0.665714  0.649524  0.649524  0.725664
# 3637  2024-12-25  7.010000  0.667619  0.670476  0.659048  0.664762  0.649409
# 3638  2024-12-26  6.940000  0.660952  0.667619  0.655238  0.664762  0.385300
# 3639  2024-12-27  6.940000  0.660952  0.663810  0.649524  0.660952  0.367788
#
# ...

# %%
total.groupby()

# %%
total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 618800 entries, 0 to 3639
# Data columns (total 22 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   index         618800 non-null  object
#  1   price         618800 non-null  float64
#  2   close         618800 non-null  float64
#  3   high          618800 non-null  float64
#  4   low           618800 non-null  float64
#  5   open          618800 non-null  float64
#  6   volume        618800 non-null  float64
#  7   ticker        618800 non-null  object
#  8   day           618800 non-null  float64
#  9   macd          618800 non-null  float64
#  10  boll_ub       618800 non-null  float64
#  11  boll_lb       618800 non-null  float64
#  12  rsi_30        618800 non-null  float64
#  13  cci_30        618800 non-null  float64
#  14  dx_30         618800 non-null  float64
#  15  close_30_sma  618800 non-null  float64
#  16  close_60_sma  618800 non-null  float64
# ...
